# %% [markdown]
# #### Imports

# %%
import pandas as pd
from sklearn import tree
from treeviz import tree_print
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Tennis Dataset

# %% [markdown]
# #### Creates the dataframe

# %%
tennis_df = pd.read_csv('tennis_numeric.csv')

# %%
tennis_df
# Out:
#     outlook_sunny  outlook_overcast  outlook_rainy  temperature  humidity  \
# 0               1                 0              0           85        85
# 1               1                 0              0           80        90
# 2               0                 1              0           83        86
# 3               0                 0              1           70        96
# 4               0                 0              1           68        80
# 5               0                 0              1           65        70
# 6               0                 1              0           64        65
# 7               1                 0              0           72        95
# 8               1                 0              0           69        70
# 9               0                 0              1           75        80
# 10              1                 0              0           75        70
# 11              0                 1              0           72        90
# ...

# %% [markdown]
# #### Creates the entropy tree

# %%
tennis_dtree = tree.DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# ### Split the data into numerical and categorical

# %% [markdown]
# #### Categorical

# %%
tennis_categorical = pd.DataFrame(tennis_df['play'])

# %%
tennis_categorical.head()
# Out:
#   play
# 0   no
# 1   no
# 2  yes
# 3  yes
# 4  yes

# %% [markdown]
# #### Numerical

# %%
tennis_numerical = tennis_df.drop(['play'], axis=1)

# %%
tennis_numerical.head()
# Out:
#    outlook_sunny  outlook_overcast  outlook_rainy  temperature  humidity  \
# 0              1                 0              0           85        85
# 1              1                 0              0           80        90
# 2              0                 1              0           83        86
# 3              0                 0              1           70        96
# 4              0                 0              1           68        80
#
#    windy
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0

# %% [markdown]
# #### Create the entropy tree

# %%
tennis_dtree = tree.DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# #### Build the model

# %%
tennis_dtree.fit(tennis_numerical, tennis_categorical)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# #### Print the tree

# %%
tree_print(tennis_dtree, tennis_numerical)
# Out:
# if outlook_overcast =< 0.5:
#   |then if humidity =< 82.5:
#   |  |then if temperature =< 66.5:
#   |  |  |then no
#   |  |  |else yes
#   |  |else if humidity =< 95.5:
#   |  |  |then no
#   |  |  |else yes
#   |else yes
# <------->
# Tree Depth:  3

# %% [markdown]
# #### Produces the array of labels

# %%
predict_array = tennis_dtree.predict(tennis_numerical)

# %%
predicted_labels = pd.DataFrame(predict_array)

# %%
predicted_labels.columns = ['Play']

# %% [markdown]
# #### A list of the predicted labels

# %%
predicted_labels.head()
# Out:
#   Play
# 0   no
# 1   no
# 2  yes
# 3  yes
# 4  yes

# %% [markdown]
# #### A list of the actual labels

# %%
tennis_categorical.head()
# Out:
#   play
# 0   no
# 1   no
# 2  yes
# 3  yes
# 4  yes

# %% [markdown]
# #### Checks to see if the predicted label and target label are the same

# %%
predicted_labels.equals(tennis_categorical)
# Out:
# False

# %% [markdown]
# # Our Dataset

# %% [markdown]
# #### Createst the DateFrame

# %%
df = pd.read_csv('Garch.csv')

# %%
df
# Out:
#       Unnamed: 0    date        day      dm       ddm      bp      cd  \
# 0              1  800102  wednesday  0.5861       NaN  2.2490  0.8547
# 1              2  800103   thursday  0.5837 -0.004103  2.2365  0.8552
# 2              3  800104     friday  0.5842  0.000856  2.2410  0.8566
# 3              4  800107     monday  0.5853  0.001881  2.2645  0.8538
# 4              5  800108    tuesday  0.5824 -0.004967  2.2560  0.8553
# 5              6  800109  wednesday  0.5834  0.001716  2.2650  0.8565
# 6              7  800110   thursday  0.5807 -0.004639  2.2505  0.8583
# 7              8  800111     friday  0.5819  0.002064  2.2640  0.8591
# 8              9  800114     monday  0.5817 -0.000344  2.2835  0.8580
# 9             10  800115    tuesday  0.5788 -0.004998  2.2830  0.8576
# 10            11  800116  wednesday  0.5808  0.003449  2.2675  0.8602
# 11            12  800117   thursday  0.5807 -0.000172  2.2770  0.8620
# ...

# %% [markdown]
# ### Split the dataset into numerical and categorical

# %% [markdown]
# #### Numerical

# %%
df_numerical = df.drop(['Unnamed: 0', 'date', 'day'], axis=1)

# %%
df_numerical.head()
# Out:
#        dm       ddm      bp      cd        dy      sf
# 0  0.5861       NaN  2.2490  0.8547  0.004206  0.6365
# 1  0.5837 -0.004103  2.2365  0.8552  0.004187  0.6357
# 2  0.5842  0.000856  2.2410  0.8566  0.004269  0.6355
# 3  0.5853  0.001881  2.2645  0.8538  0.004315  0.6373
# 4  0.5824 -0.004967  2.2560  0.8553  0.004257  0.6329

# %% [markdown]
# #### Categorical

# %%
df_categorical = pd.DataFrame(df['day'])

# %%
df_categorical.head()
# Out:
#          day
# 0  wednesday
# 1   thursday
# 2     friday
# 3     monday
# 4    tuesday

# %% [markdown]
# #### To create our entropy tree

# %%
dtree = tree.DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# #### Build the models

# %%
dtree.fit(df_numerical, df_categorical)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-92731c77af71> in <module>
# ----> 1 dtree.fit(df_numerical, df_categorical)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     799             sample_weight=sample_weight,
#     800             check_input=check_input,
# --> 801             X_idx_sorted=X_idx_sorted)
#     802         return self
#     803
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ...

# %% [markdown]
# #### Print the tree

# %%
tree_print(dtree, df_numerical)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-afb62cb4d20f> in <module>
# ----> 1 tree_print(dtree, df_numerical)
#
# ~\Documents\URI\Super SR\Spring\CSC310\Python\A3\treeviz.py in tree_print(clf, X)
#      17     X : The original training set
#      18     """
# ---> 19     tlevel = _tree_rprint('', clf, X.columns, clf.classes_)
#      20     print('<',end='')
#      21     for i in range(3*tlevel - 2):
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'classes_'
