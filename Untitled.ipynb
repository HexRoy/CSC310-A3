# %%
import pandas as pd
from sklearn import tree
from treeviz import tree_print
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('tennis_numeric.csv')

# %%
dataset
# Out:
#     outlook_sunny  outlook_overcast  outlook_rainy  temperature  humidity  \
# 0               1                 0              0           85        85
# 1               1                 0              0           80        90
# 2               0                 1              0           83        86
# 3               0                 0              1           70        96
# 4               0                 0              1           68        80
# 5               0                 0              1           65        70
# 6               0                 1              0           64        65
# 7               1                 0              0           72        95
# 8               1                 0              0           69        70
# 9               0                 0              1           75        80
# 10              1                 0              0           75        70
# 11              0                 1              0           72        90
# ...

# %%
treeprint.treeviz.py dataset
# Out:
#   File "<ipython-input-4-6b65432148e8>", line 1
#     treeprint.treeviz.py dataset
#                                ^
# SyntaxError: invalid syntax
